# %%
import pandas as pd
import os
from os.path import join
import sys
from bokeh.io import show, output_notebook
from bokeh.charts import Scatter

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ff3652d8-ce2d-4014-a910-5bca75c41c90">Loading BokehJS ...</span>
#     </div>

# %%
from config import DATA_DIR

# %% [markdown]
# ## Load Data

# %% [markdown]
# Download data to DATA_DIR from
# https://www.kaggle.com/ksuchris2000/oklahoma-earthquakes-and-saltwater-injection-wells/data

# %%
wells = pd.read_csv(join(DATA_DIR, 'InjectionWells.csv'))
wells.shape
# Out:
# (11126, 21)

# %%
wells.columns
# Out:
# Index(['API#', 'Operator', 'Operator ID', 'WellType', 'WellName', 'WellNumber',
#        'OrderNumbers', 'Approval Date', 'County', 'Sec', 'Twp', 'Rng', 'QQQQ',
#        'LAT', 'LONG', 'PSI', 'BBLS', 'ZONE', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
wells = wells.drop(columns=wells.columns[-3:])

# %%
wells = wells.dropna(axis=0)
wells.shape
# Out:
# (9656, 18)

# %%
def convert_to_float(x):
    """
    Converts a string to a float and returns null for values that don't match
    """
    try:
        return float(x.replace(',', ''))
    except Exception:
        return None
convert_to_float('1,550'), convert_to_float('ASDFL#_V@@R')
# Out:
# (1550.0, None)

# %%
def convert_series_to_float(pd_series):
    return pd_series.apply(convert_to_float)

# %%
wells.loc[:, 'PSI'] = wells['PSI'].str.replace(',','').apply(convert_to_float)

# %%
wells.loc[:, 'BBLS'] = convert_series_to_float(wells['BBLS'])

# %%
show(Scatter(wells, 'BBLS', 'PSI'))
# Out:
#     <div class="plotdiv" id="d4da8c49-6485-4f0c-95d1-562bc0139a7b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d4da8c49-6485-4f0c-95d1-562bc0139a7b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd4da8c49-6485-4f0c-95d1-562bc0139a7b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"753cce8b-9fab-45fe-9efe-9551df34e6aa":{"roots":{"references":[{"attributes":{"plot":{"id":"f7661777-d47d-442f-90b4-72add7d4106b","subtype":"Chart","type":"Plot"}},"id":"caecc234-8a0f-44e8-bc8c-8b0cca3702f0","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f7661777-d47d-442f-90b4-72add7d4106b","subtype":"Chart","type":"Plot"}},"id":"c8a35f26-f2b2-49b6-af04-bb013660e702","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,n ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %%
wells.dtypes
# Out:
# API#             float64
# Operator          object
# Operator ID      float64
# WellType          object
# WellName          object
# WellNumber        object
# OrderNumbers     float64
# Approval Date     object
# County            object
# Sec               object
# Twp               object
# Rng               object
# QQQQ              object
# LAT              float64
# LONG             float64
# PSI              float64
# BBLS             float64
# ZONE              object
# dtype: object

# %%
float_types = wells.dtypes == float
float_types.values
# Out:
# array([ True, False,  True, False, False, False,  True, False, False,
#        False, False, False, False,  True,  True,  True,  True, False])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.linear_model import Ridge

# %%
r = Ridge()

# %%
y_col = 'BBLS'

# %%
wells_float = wells.select_dtypes(include='float').dropna(axis=0)

# %%
wells_float = wells_float.drop(y_col, axis=1)
x = wells_float

# %%
y = wells_float[y_col]

# %%
x.shape
# Out:
# (9656, 6)

# %%
assert x.shape[0] == y.shape[0]

# %%
x.columns
# Out:
# Index(['API#', 'Operator ID', 'OrderNumbers', 'LAT', 'LONG', 'PSI'], dtype='object')

# %%
x.head()
# Out:
#            API#  Operator ID  OrderNumbers        LAT      LONG     PSI
# 0  3.500300e+09      19499.0      133856.0  36.900324 -98.21826  2500.0
# 1  3.500300e+09       4030.0      470258.0  36.896636 -98.17772  2400.0
# 2  3.500321e+09      22182.0      329426.0  36.806113 -98.32584  1050.0
# 3  3.500321e+09      22281.0      281652.0  36.888589 -98.31853  3152.0
# 4  3.500321e+09       4030.0      470257.0  36.892128 -98.19462  1000.0

# %%
r.fit(x, y)
# Out:
# /home/bobdavis/.virtualenvs/machine-learning-examples/lib/python3.5/site-packages/scipy/linalg/basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.742777922766492e-18 / 1.1102230246251565e-16
#   RuntimeWarning)
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
r.score(x, y)
# Out:
# 0.13981939618988892

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(x, y)
rfr.score(x, y)
# Out:
# 0.9501910353213893

# %%
le = LabelEncoder()

# %%
wells_objects = wells.select_dtypes(exclude='float')
wells_objects.shape
# Out:
# (9656, 11)

# %%
wells_objects.head()
# Out:
#                                  Operator WellType                  WellName  \
# 0                   PHOENIX PETROCORP INC       2R  SE EUREKA UNIT-TUCKER #1
# 1                CHAMPLIN EXPLORATION INC       2R               CHRISTENSEN
# 2                      LINN OPERATING INC       2R          NE CHEROKEE UNIT
# 3  SANDRIDGE EXPLORATION & PRODUCTION LLC       2R                     VELMA
# 4                CHAMPLIN EXPLORATION INC       2R                      GRAY
#
#   WellNumber Approval Date   County Sec  Twp  Rng         QQQQ      ZONE
# 0         21      9/6/1977  ALFALFA  13  28N  10W      C-SE SE  CHEROKEE
# 1          1    11/27/2002  ALFALFA  21  28N  09W      C-NW NW  RED FORK
# 2         85     8/19/1988  ALFALFA  24  27N  11W        SE NE  RED FORK
# 3       2-19     7/11/1985  ALFALFA  19  28N  10W  SW NE NE SW  RED FORK
# 4         1A    11/27/2002  ALFALFA  20  28N  09W     SE SW NW  RED FORK

# %%
wells_objects.iloc[:, 0].sample(10)
# Out:
# 2240       CITATION OIL & GAS CORPORATION
# 8314                              TAT INC
# 10939                   CHEW-COAST & SONS
# 10780         SAND BOY PRODUCTION COMPANY
# 7873                   ENERGYQUEST II LLC
# 151                        J-BREX COMPANY
# 805        CITATION OIL & GAS CORPORATION
# 9441     TARGA PIPELINE MID-CONTINENT LLC
# 3009         MID-CON ENERGY OPERATING LLC
# 4621              RED RIVER PETROLEUM INC
# Name: Operator, dtype: object

# %%
wells_objects_encoded = le.fit_transform(wells_objects.iloc[:, 0])
wells_objects_encoded.shape
# Out:
# (9656,)

# %%
import numpy as np
np.random.choice(wells_objects_encoded, 30)
# Out:
# array([  82,  172, 1390, 1136,  257, 1073,  230,  260,  214,  257,  828,
#         780,  668,  271,  764,  159, 1104,  786,  234,  264,  624,  739,
#        1056,  624, 1198, 1114,  933,  224, 1043, 1149])

# %%
def encode_objects(pd_series):
    return le.fit_transform(pd_series)

# %%
x_objects = {}
for _, col in wells_objects.iteritems():
    x_objects[_] = encode_objects(col)

# %%
x_objects = pd.DataFrame.from_dict(x_objects)

# %%
x_objects.shape, wells_float.shape
# Out:
# ((9656, 11), (9656, 7))

# %%
wells_encoded = x_objects.join(wells_float)
wells_encoded.shape
# Out:
# (9656, 17)

# %%
x = wells_encoded.dropna()
x.shape
# Out:
# (8263, 17)

# %%
y = y[x.index]

# %%
y.shape
# Out:
# (8263,)

# %%
x.columns
# Out:
# Index(['Approval Date', 'County', 'Operator', 'QQQQ', 'Rng', 'Sec', 'Twp',
#        'WellName', 'WellNumber', 'WellType', 'ZONE', 'API#', 'Operator ID',
#        'OrderNumbers', 'LAT', 'LONG', 'PSI'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
r.fit(x_train, y_train)
train_score = r.score(x_train, y_train)
val_score = r.score(x_test, y_test)
# Out:
# /home/bobdavis/.virtualenvs/machine-learning-examples/lib/python3.5/site-packages/scipy/linalg/basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.9330730826984756e-18 / 1.1102230246251565e-16
#   RuntimeWarning)

# %%
train_score, val_score
# Out:
# (0.16279121593147838, 0.1749480909834079)

# %%
y_test_pred = r.predict(x_test)

# %%
show(Scatter(pd.DataFrame.from_dict({'y_pred': y_test_pred, 'y_actual': y_test}), 'y_actual', 'y_pred'))
# Out:
#     <div class="plotdiv" id="f5239df8-23b5-497c-8565-100d4b396f74"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5239df8-23b5-497c-8565-100d4b396f74");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5239df8-23b5-497c-8565-100d4b396f74' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a15739ac-5b44-4ec1-aff1-ddfa1cc3761c":{"roots":{"references":[{"attributes":{"callback":null,"end":127.82788164,"start":-233.75769804},"id":"963fa075-104f-467f-80a5-d6345e696eb2","type":"Range1d"},{"attributes":{"data_source":{"id":"d838a2ef-c1b0-4290-9b29-4aa7e632c73f","type":"ColumnDataSource"},"glyph":{"id":"fa6f070d-6378-44c5-82d6-c597090ed23e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e31b4038-c2bc-4630-8483-86e8fc369ddb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e743d340-73ab-4954-b351-4dca6e463fd4","type":"ColumnDataSource"},"glyph":{"id":"9cda4e42-db52-4bae-809c-bfd991e63600","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"97b7dcf6-2454-44da-a56e-af909589027d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"PSI":[2380.0,2380.0],"chart_index":[{"PSI":2380.0},{"PSI":2380.0}],"x_values":[0.0,34.4042739],"y_values":[0.0,-97.57860550000001]}},"id":"c8137705-893e-41f7-b2b4-80e5f18ecef0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4c4688a2-d9af-4c44-af1c-60d63178940e","type":"ColumnDataSource"},"glyph":{"id":"73370f53-f7a6-4225-959b-d471385eeeb4","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e541e1da-8108-44f8-9e12-59e2a7fae518","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#c33ff3"},"line_color":{"value":"#c33ff3"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"752b29e1-debb-42d0-a43d-4464a3f9bbfb","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#00ad9c"},"line_color":{"value":"#00ad9c"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"
"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0},{"PSI":1800.0}],"x_values":[35.373860799999996,35.9040783,34.9236285,34.926446,34.9264856,34.9337768,34.930096899999995,34.93391870000001,34.9391805,34.3388675,34.162752000000005,34.3226141,34.165663,34.3178799,35.912178499999996,36.267266799999994,34.5701046,34.574615,34.5518615,34.7352235,34.705443200000005,35.11 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[31]</strong>&gt;</code></p>

# %%
wells[['LAT', 'LONG']].describe()
# Out:
#                 LAT          LONG
# count  11125.000000  11125.000000
# mean      35.207878    -96.849979
# std        2.689511      7.575851
# min        0.000000   -203.625566
# 25%       34.441536    -97.631560
# 50%       35.154533    -97.366105
# 75%       36.124345    -96.537961
# max       73.986030     97.695750

# %%
wells['LONG'].median()
# Out:
# -97.3661053

# %%
## Code adapated from:: http://www.bigendiandata.com/2017-06-27-Mapping_in_Jupyter/

from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=wells['LAT'].median(), lng=wells['LONG'].median(), map_type="roadmap", zoom=6)

plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options)
plot.title = "Oklahoma Wells"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
#plot.api_key = os.getenv('GOOGLE_MAPS_API_KEY')

source = ColumnDataSource(
    data=dict(
        lat=wells['LAT'].values,
        lon=wells['LONG'].values,
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
output_file(join(DATA_DIR, "gmap_plot.html"))
show(plot)
# Out:
# INFO:bokeh.core.state:Session output file './data/gmap_plot.html' already exists, will be overwritten.
#     <div class="plotdiv" id="fcf404ac-ff17-47ea-b26c-e4955bf3a5a8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fcf404ac-ff17-47ea-b26c-e4955bf3a5a8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fcf404ac-ff17-47ea-b26c-e4955bf3a5a8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a5452765-242d-490e-a852-d0cff909e34c":{"roots":{"references":[{"attributes":{"callback":null},"id":"448532e5-5011-439a-84cc-be0aa631f4bd","type":"Range1d"},{"attributes":{"map_options":{"lat":35.154532700000004,"lng":-97.3661053,"map_type":"roadmap","zoom":6},"renderers":[{"id":"5b53df1a-6456-4865-b0e9-125f61976bc6","type":"GlyphRenderer"},{"id":"45de9522-d17e-41c1-8a72-a09e62f2da1d","type":"BoxAnnotation"}],"title":"Oklahoma Wells","tool_events":{"id":"7fde4356-385e-4260-a593-2c9bda299993","type":"ToolEvents"},"tools":[{"id":"228e141d-3a82-447f-949d-4c8e0c72ef35","type":"PanTool"},{"id":"85e45854-ff86-475d-8f28-35a11a30789c","type":"WheelZoomTool"},{"id":"cd03bcc8-85fd-4a29-80e1-fe7b05998310","type":"BoxSelectTool"}],"x_range":{"id":"448532e5-5011-439a-84cc-be0aa631f4bd","type":"Range1d"},"y_range":{"id":"bd63ab2c-7e01-4fcb-b0ab-342af1ecf08d","type":"Range1d"}},"id":"40326c71-9d40-44a3-9ab0-b37b4a921baf","type":"GMapPlot"},{"attributes":{"callback":null},"id":"bd63ab2c-7e01-4fcb-b0ab-342af1ecf08d","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"3fde4156-b7d5-4e02-9113-6f9e97bf6a72","type":"Circle"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[41]</strong>&gt;</code></p>

# %%
wells['County'].unique()
# Out:
# array(['ALFALFA', 'ATOKA', 'BEAVER', 'BECKHAM', 'BLAINE', 'BRYAN',
#        'CADDO', 'CANADIAN', 'CARTER', 'CIMARRON', 'CLEVELAND', 'COAL',
#        'COMANCHE', 'COTTON', 'CRAIG', 'CREEK', 'CUSTER', 'DEWEY', 'ELLIS',
#        'GARFIELD', 'GARVIN', 'GRADY', 'GRANT', 'GREER', 'HARMON',
#        'HASKELL', 'HUGHES', 'JACKSON', 'JEFFERSON', 'KAY', 'KINGFISHER',
#        'KIOWA', 'LATIMER', 'LEFLORE', 'LINCOLN', 'LOGAN', 'LOVE',
#        'MCCLAIN', 'MCINTOSH', 'MAJOR', 'MARSHALL', 'MAYES', 'MURRAY',
#        'MUSKOGEE', 'NOBLE', 'NOWATA', 'OKFUSKEE', 'OFUSKEE', 'OKLAHOMA',
#        'OKMULGEE', 'PAWNEE', 'PAYNE', 'PITTSBURG', 'PONTOTOC',
#        'POTTAWATOMIE', 'ROGER MILLS', 'ROGERS', 'SEMINOLE', 'STEPHENS',
#        'TEXAS', 'TILLMAN', 'TULSA', 'WAGONER', 'WASHINGTON', 'WOODS',
#        'WOODWARD', nan], dtype=object)

# %%
wells.columns
# Out:
# Index(['API#', 'Operator', 'Operator ID', 'WellType', 'WellName', 'WellNumber',
#        'OrderNumbers', 'Approval Date', 'County', 'Sec', 'Twp', 'Rng', 'QQQQ',
#        'LAT', 'LONG', 'PSI', 'BBLS', 'ZONE'],
#       dtype='object')

# %%
wells['WellType'].unique()
# Out:
# array(['2R', '2D', 'CDW', 'GS', '2RSI', '2d', nan], dtype=object)

# %%
wells['Sec'].unique()
# Out:
# array(['13', '21', '24', '19', '20', '3', '5', '36', '15', '34', '18',
#        '10', '17', '8', '26', '30', '32', '28', '2', '29', '27', '14',
#        '35', '23', '1', '22', '25', '7', '31', '12', '6', '11', '16', '9',
#        '33', '4', '14-12', '09', nan], dtype=object)

# %%
wells['Twp'].unique()
# Out:
# array(['28N', '27N', '24N', '25N', '26N', '29N', '16N', '02N', '01N',
#        '06N', '05N', '04N', '03N', '10N', '09N', '08N', '11N', '17N',
#        '15N', '18N', '14N', '19N', '05S', '06S', '07N', '12N', '13N',
#        '02S', '04S', '01S', '03S', '21N', '22N', '23N', '20N', '07S',
#        '08S', nan], dtype=object)

# %%
wells['Rng'].unique()
# Out:
# array(['10W', '09W', '11W', '12W', '12E', '21E', '26E', '22E', '25E',
#        '20E', '24E', '28E', '23E', '27E', '21W', '26W', '25W', '23W',
#        '22W', '24W', '13W', '07E', '08E', '05W', '08W', '02W', '01W',
#        '03W', '01E', '09E', '04E', '05E', '04W', '10E', '19E', '18E',
#        '11E', '17W', '14W', '20W', '19W', '18W', '15W', '16W', '06W',
#        '07W', '02E', '03E', '06E', '14E', '15E', '13E', '17E', '16E',
#        '13E ', nan], dtype=object)

# %%
wells['QQQQ'].unique()
# Out:
# array(['C-SE SE', 'C-NW NW', 'SE NE', ..., 'CT SW SE', 'CT SW SW', nan],
#       dtype=object)
